# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import requests

from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %%
import pandas as pd

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
questions = SITE.fetch('questions', fromdate=1577775600, todate=1580454000)

# %%
df = pd.DataFrame(questions)
df
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'tags': ['java', 'logging', 'java-9'], 'owner...
# 1    {'tags': ['node.js', 'mongodb', 'mongoose', 'k...
# 2    {'tags': ['java', 'swing', 'mvvm', 'rx-java'],...
# 3    {'tags': ['xcode', 'xcode11', 'xcode-instrumen...
# 4    {'tags': ['swift', 'xcode', 'localization'], '...
# ..                                                 ...
# 495  {'tags': ['ios', 'swift', 'ios13.2'], 'owner':...
# 496  {'tags': ['stm32', 'nucleo', 'st'], 'owner': {...
# 497  {'tags': ['android', 'miui'], 'owner': {'reput...
# 498  {'tags': ['python', 'dns', 'twisted'], 'owner'...
# 499  {'tags': ['html', 'powershell', 'encoding', 'm...
#
# [500 rows x 7 columns]

# %%
items = df["items"]
items
# Out:
# 0      {'tags': ['java', 'logging', 'java-9'], 'owner...
# 1      {'tags': ['node.js', 'mongodb', 'mongoose', 'k...
# 2      {'tags': ['java', 'swing', 'mvvm', 'rx-java'],...
# 3      {'tags': ['xcode', 'xcode11', 'xcode-instrumen...
# 4      {'tags': ['swift', 'xcode', 'localization'], '...
#                              ...
# 495    {'tags': ['ios', 'swift', 'ios13.2'], 'owner':...
# 496    {'tags': ['stm32', 'nucleo', 'st'], 'owner': {...
# 497    {'tags': ['android', 'miui'], 'owner': {'reput...
# 498    {'tags': ['python', 'dns', 'twisted'], 'owner'...
# 499    {'tags': ['html', 'powershell', 'encoding', 'm...
# Name: items, Length: 500, dtype: object

# %%
items[0]
# Out:
# {'tags': ['java', 'logging', 'java-9'],
#  'owner': {'reputation': 8987,
#   'user_id': 1751640,
#   'user_type': 'registered',
#   'accept_rate': 75,
#   'profile_image': 'https://i.stack.imgur.com/MA5Ln.png?s=128&g=1',
#   'display_name': 'Mordechai',
#   'link': 'https://stackoverflow.com/users/1751640/mordechai'},
#  'is_answered': False,
#  'view_count': 44,
#  'answer_count': 1,
#  'score': 4,
#  'last_activity_date': 1580722935,
#  'creation_date': 1580338653,
#  'last_edit_date': 1580339212,
#  'question_id': 59976828,
#  'link': 'https://stackoverflow.com/questions/59976828/difference-between-java-util-logging-logger-and-java-lang-system-logger',
#  'title': 'Difference between &#39;java.util.logging.Logger&#39; and &#39;java.lang.System.Logger&#39;'}

# %%
questions_of_the_month = []
for item in range(len(items)):
    question = df["items"][item]["title"]
    questions_of_the_month.append(question)
    
questions_of_the_month
# Out:
# ['Difference between &#39;java.util.logging.Logger&#39; and &#39;java.lang.System.Logger&#39;',
#  'How to add MongoDB Atlas cloud database in KeystoneJS v5',
#  'RxJavaSwing + MVVM with Portrait Landscape Views',
#  'How to enable network debugging in Xcode debug navigation tab',
#  'Xcode Kurdish localization issue',
#  'Mysql Web-Farm Linux Host',
#  'Converting EMF Image from MS Word to BufferedImage',
#  'Plotly dash - Dynamically displaying a ndarray image',
#  'Loading MarkerClusters while the bounding boxs changes position and display',
#  'NGINX Ingress with regex',
#  'How to generate the JWT token using Prisma API?',
#  'Getting error while SSH to VM of Azure Kubernetes',
#  'Xquery giving error on arrow on marklogic qconsole',
#  'How to securely store the amazon access token for Amazon KMS',
#  'HTPP request Ajax converted to Laravel for an external api',
#  'Draggable widget blocks scroll gesture',
#  'azure:storage:storage_exception m_http_status_code = 0 when using invalid credentials',
#  'CultureInfo: Compare including parent',
#  'Venv fails in CentOS, ensurepip missing',
#  'Token mismatch error in laravel post request',
#  'Node.js Access Values from Anonymous function',
#  'Why do I get a 405 response for a delete on live but not on local Laravel project?',
#  'Google App Script to copy rows into dynamically created tabs based on the value of a column',
#  'Apache, how to handle unknown php file like standard URLs?',
#  'Firebase Authentication in Unity Rejects &quot;Sign In With Apple&quot; Tokens',
#  'How to use queues with micropython and ev3dev',
#  'export the value to the excel file and validating the excel output value to the defined value in katalon studio?',
#  'How do I allow Xcode to access the microphone?',
#  'HTML local files - parse',
#  'Data binding and types with Katalon Studio',
#  'not establish a connectio',
#  'Difficulties with implementing a class',
#  'Export a PDF in Winforms with PDFsharp',
#  'How To Convert Dropdown to checkbox in View page',
#  'Customising a standard B2C User Flow without updating client',
#  'Can argv be changed at runtime (not by the app itself)',
#  'Localisation Settings Not Changing the System Defined Text in Swift 4.2',
#  'how can i create popup static in leaflet for set value by document.getElementById(idPopUPImage).innerHTML?',
#  'Homestead server times out when route not found',
#  'Upgrading to torch 1.2.0 cause memory leak and downgrading to torch 0.4.1.post2 removes memory leak but slow down the inference time of the model',
#  'Vue.js + Vue2Leaflet: update computed property on map moveend',
#  'netlify form submission not showing file on the back end, all other fields are showing up but not the file upload',
#  'couldn&#39;t sync local folder to gcloud',
#  'BQ load JSON File with Array of Array',
#  'HandlebarsJS: Hyperlink containing placeholder?',
#  'VS show alot of errors (E1696, E0020) and warnings (C26451, C4754) with a new project',
#  'useEffect in depth/ use of useEffect?',
#  'gridTimeDay Events needed +more in the day view using fullcalendar',
#  'Excel Macro - Loop through 2 pivot tables',
#  'How to connect Spotify SDK to View Controller in Xcode 11',
#  'UncaughtReference Error: function is not defined at HTMLInputElement.onclick after using webpack',
#  'VBA - Trying to Input text and click Search button, All within a Table, within a Form, No ID Element, only Class Element',
#  'How to hide toolbar inside collapsing toolbar layout?',
#  'How to create reusable component in UCD(UrbanCode Deploy)?',
#  'How to store customfields from atlassian&#39;s Json Response e.g.(customfield_10020) which is coming dynamic everytime in c#',
#  'How to disable auto-start AVPlayer in wkwebview video',
#  'Roles Metadata Tables in Snowflake',
#  'convert individual factors (within rows) into individual columns and transfer affiliated numbers over remaining factor',
#  'Questions about options in http settings &quot;overide host name&quot; and &quot;pick host name from backend address&quot;',
#  'Keep Python3 script running when changing user on Linux',
#  'Is it possible to use Spring to create a user storage spi (jpa based) in Keycloak?',
#  'Correct byteoffset and complete line with grep',
#  'What is difference between AI Notebook and Cloud Datalab in GCP?',
#  'What is the prebid member id?',
#  'Best way to reload modules that have changed in Jupyter Lab?',
#  'How to add a plugin in @ckeditor/ckeditor5-react manually?',
#  'Trying to get a Regular expression pattern which can replace everything else but will keep only negative sign &quot;-&quot; and all digits in a cell',
#  'Jhipster, How to Lazy Load entities ... Pom config,',
#  'CollectionView Cells are not visible',
#  'x3d inline example not working in internet explorer',
#  'Microsoft office.js Excel add-in - is it possible to detect excel SAVE action performed by user?',
#  'Selenium vs Cypress.io',
#  'How to use Open Type Font (OTF) in Flutter?',
#  'Unable to click on tile using Protractor',
#  'Not assignable to type IntrinsicAttributes &amp; IntrinsicClassAttributes React.js',
#  'Resilience4j RateLimiter seems to ignore configuration',
#  'ActiveMQ Redeliver Rejected messages Amqp.NET Lite C#',
#  'Find Top N Most Frequent Sequence of Numbers in List of a Billion Sequences',
#  'CameraPreview does not take all the place',
#  'Decode Access Token getting from frontend IOS application to fetch user information using Okta and Node JS',
#  'Can not connect to local server using dnsmasq with rails',
#  'Ionic 3 How to display toast on modal?',
#  'Insert data into a table from comma separated string (T-SQL)',
#  'Responding to Conversations async: Graph or Bot?',
#  'Efficient way of tracking Ordinal data movement over time',
#  'WPF Grid in Powershell get cutted in height',
#  'Separate lines and circles in an image using OpenCV in python',
#  'OOM when reading data to Pandas from MongoDB using pymongo client',
#  'Avoid re-rendering in React when switching between tabs',
#  'Besides UI, any other pros that Blue Ocean for Jenkins has comparing with Jenkins pipeline plugin?',
#  'Cannot rename the downloaded file',
#  'AutoMl Edge Model Showing Only Image',
#  'Conflicting jackson-jaxrs provider in WildFly with EAR deployment',
#  'FlatFileItemWriterBuilder-headerCallback() get number of rows written',
#  'Get authentication token from AWS EKS using the AWS Java SDK v2',
#  'Webpack Dev Server 4 Proxy problem with multiple routes',
#  'Microsoft AnalysisServices - start and stop server using Azure Functions',
#  'Getting MS-Access form to save invisible combo boxes as a null or 0 value in query and table',
#  'ddev start - failed to load any docker-compose.*y*l files',
#  'How to programmatically make a TreeView visible',
#  'How to programmatically make a TreeView visible',
#  'Imageview cropping mechanism best approach',
#  'redirection fails when called after deleting application cookies from the browser says cors error',
#  'Elasticsearch + NEST: Use token-filter only for comparisation but not on analyzers result',
#  'pyspark daterange calculations in spark',
#  'Benefits of using Cloud Endpoints',
#  '(NODEJS) How can I use puppeteer to send a command into the console?',
#  'Why does my razor view throw InvalidOperationException for the wrong part of the code?',
#  'New MicrosoftTeams.authentication.getAuthToken is not a MS Graph Bearer: token?',
#  'Angular Dynamic Button Implement In Html',
#  '3 days worth of RR interval in movesense DataLogger',
#  'How can I accelerate the caching in Spark (Pyspark)?',
#  'Unsupported operation Exception aries in my application I dnt know where the issue aries.Please some one help me to fix it',
#  'Default Props in stateful (using hooks) functional components',
#  'mXparser result rounding',
#  'Editext.setSelection with Seekbar Android',
#  'How do I plot in real time in Jupyter',
#  'How to get microdata working in CKEditorWidget',
#  'How to center align this element using css selector?',
#  'Divide by the sum of account balances for the last 12 months with f.lag (looking for improvement)',
#  'Specify order of columns in SELECT with UNION using Django ORM',
#  'Prometheus Targets Errors',
#  'ColorPreview for Hex Color in C# in VS',
#  'IntelliJ Test Code Coverage not displayed in code',
#  'Webview failure when internet is off',
#  '$_FILES is empty using yii2 framework',
#  'start new instance of process after last one terminates, or how to update $timer.add_tick method',
#  'Configuring multiple scheme in iOS causes mismatch in flavors',
#  'can one have multiple html files in a single template directory in django?',
#  'Converting packed 64-bit integers to packed 8-bit integers with signed saturation using AVX512',
#  '10.2.25-MariaDB not allowing data in multiple languages',
#  'Elastic search query for getting array of values',
#  'Unit testing that localStorage.getItem has been called on document ready?',
#  'yii2 redirect any page to login page after session timeout',
#  'Is it possible to change the BLE scan window and scan interval in a Raspberry Pi 3b+ using BlueZ?',
#  'Visual Studio Code take too much time for intelli-sense while I pressing Ctrl + space?',
#  'How to flash a firmware with J-Tag through Python?',
#  'WO Service Address: Manually refine the XY without nulling-out the service address?',
#  'WOSERVICEADDRESS X &amp; Y: Differentiate between sources (SA vs. user-defined)',
#  'Loop through array and return multiple rows based one or more search criterias',
#  'Sequences’ Similarity Matching in Pandas',
#  'Why is lodash not working when I import it in Vue.js',
#  'Html Select/Dropdown&#39;s list isn&#39;t directly underneath - it&#39;s offset by the scrollbar',
#  'how to get database value from orm and field name get from string in odoo 8',
#  'can anyone help me, why I am getting food is not defined error ? I have attached the structure of Django module',
#  'How to add transparent background while open the side menu in swift?',
#  'Can a Python script activate a virtual environment and then trigger an interactive pdb session within it?',
#  'How to show the id of outliers on a boxplot',
#  'Google App Engine &quot;Exceeded soft memory limit on &quot;',
#  'Donot Get push Notification Action when app gets killed React-native (Android)',
#  'DoneButton is not rendering in &#39;react-native-app-intro-slider-rerender-on-prop-change&#39;',
#  'Broadcast receiver is not called on real devices',
#  'CanDeactivate guards does not runs as expected, after pressing browser back button',
#  '&quot;Object reference not set to an instance of an object&quot; in Microsoft Dynamics 365 CRM while adding a new Order Product record',
#  'Calculating hours using JavaScript',
#  'How to support key code function in Vue.js for smart tv app',
#  'Kubernetes Nodeport only works on Pod Host',
#  'How to create a circular navigation menu using Cocoa and swift for mac desktop applications?',
#  'Toast Message In Unity C#',
#  'react-native-ui-kitten with Expo',
#  'Listing out the games installed in Windows 10 machine using c#',
#  'Not able to select QCalendarWidget popup when try to open from other window (mainwindow)',
#  'OPENJSON in SQL server returning values stored as &quot;&quot; into zeros',
#  'Meaning of user_type values in Maxmind insights API',
#  'Difference between two time values in SSRS report',
#  'Improve PostgresSQL aggregation query performance',
#  'How to send WPS request using HTML',
#  'On webpack how can I import a script without evaluate it?',
#  'Redirecting to another route ember js',
#  'How to add custom claim in ADFS 4 based on employeeId attribute and OU membership',
#  'Quantify relative position of coordinates - python',
#  'Solve non-linear equation numerically on MATLAB',
#  'Loading data to Hive using tez engine and ambari logs shows complete but logs hang without completing the Insert into those partitions',
#  'Webpack output structure changes, depending on files outside the entry',
#  'Add new records in existing hive partitioned table : PySpark',
#  'laravel markdown email render hrml in inbox',
#  'chartJS line chart not plotting values that are less than minY',
#  'Failed to deserialize data for topic XXX to avro , Error retrieving Avro schema for id XXX when using kafka-connect to sink data to postgresql',
#  'Mimic ++ operator for bookkeeping variable',
#  'ServiceController - Can&#39;t stop the service [C#]',
#  'node.js back-pressure and drain event. I encountered memory leak warning',
#  'How to keep NVCC from generating compatibility for other 11 SM architectures?',
#  'Need a little help on where to put the conversions for the textboxes',
#  'How to cancel specific Operation from OperationQueue in swift',
#  'ng-repeat is not working to refresh the display results based on filter search',
#  'Visual Basic XMLTextWriter -&gt; No Linebreaks after WriteRaw',
#  'Python item.split vertically',
#  'Anyway to control Soong when to pick Android.bp and when not?',
#  'Android Management API policy kiosk mode - System Update not applied during maintenance window',
#  'Excel sheet cut off trying to export',
#  'How to apply mutations in GRAPHQL, I encountered an error when implementing this?',
#  'Download Octopus Variables from Project Library Sets',
#  'Adding a Polygon to a SpatialPolygonsDataFrame',
#  'Android programmatically change background of Button',
#  'Preferred content size not calculating correctly',
#  'Is it possible to make python input() stick to bottom of console window while other processes print output?',
#  'How to apply b-table fields thClass or tdClass or class',
#  'Does PPO&#39;s gradient clipping really prevent r(θ) from exceeding 1&#177;epsilon?',
#  'Octopus set ASPNETCORE_ENVIRONMENT',
#  'Maria DB query with 6 LEFT JOIN very slow',
#  'Generating UUID in XSLT 1.0',
#  'Perl Dancer2 default route failing',
#  'Concurrency Handling : Synchronization vs Multiple DB Calls',
#  'Remove already selected value in jquery multiple autocomplete ajax',
#  'Espresso test fails when multiple match statements but passes with smaller match statements',
#  'No hyphenation in hyphenated block',
#  'Diagonalization + Eigendecomposition is taking more time than naive matrix multiplication',
#  'Differences between defining shallow in describe block and in every test block?',
#  'How to ignore PHP_CodeSniffer warnings',
#  'Chromium Edge:- How To display the warning that appear if you open Custom Protocol Handler again',
#  'React-native question about app.js main class/function',
#  'Jsoup cleaner version 1.12.1 returns a value other than version 1.11.2',
#  'Signing, Notarizing, hardening, etc. a macOS command-line binary?',
#  'React native application being killed by ios 13 due to exceeding limit of 80% cpu over 60 seconds',
#  'Print line with match and line above that matches another pattern',
#  'I got Unknown column error on having with count',
#  'subscribing mobx @observable using rxjs Observable but not getting on change in a deep level component (ts file)',
#  'Use the tag in GitLab webhook in jenkins build',
#  'Jsoup: get all elements before a certain element / remove all elements after a certain element',
#  'Excel Random Numbers',
#  'k-prototypes with stable results',
#  'I am not getting serial number using libusb library in C++',
#  'Join returns duplicate values',
#  'How can I sort a list of images by the number of matching tags?',
#  'Syntax error notation in python persists after error is fixed',
#  'I want to use reactive function in a R shiny app, but getting stuck in between',
#  'How to find out what cipher parameters google cloud VPN uses for IKEv1 ?',
#  'Error on external REST endpoint call using RestTemplate',
#  'Flutter - Animated process widget',
#  'Issue after deploying ASP.NET Web API to production',
#  'numWeights corresponding to mnumVertices?',
#  'Elastic Search custom logger for Java',
#  'Is it possible to externalize Electron menu template code?',
#  'Different performance of query run against same table in two different schemas',
#  'Restrict input to positive numbers in react-select&#39;s Creatable',
#  'Apache Karaf - CXF REST server address',
#  'Ghost underline even text-decoration is none',
#  'Click event on tags of many2many field in odooo 12',
#  'PHP CodeIgniter and JQuery AJAX append table row using jquery and insert all table data to database',
#  'create a text box accepting only 0-9 and get these numbers appear in another text box by adding &quot;1&quot; to each number',
#  'how to save url created from canvas.toBlob() inside PDFJS.getDocument to array?',
#  'pybind11 keeping objects alive',
#  'AIOHTTP - Application.make_handler(...) is deprecated - Adding Multiprocessing',
#  'selectizeInput in RShiny does not allow next input to be &quot;tabbed&quot; to when too many choices?',
#  'Use multiple instances of DbContext when using AddDbContextPool',
#  'Cypress types Old value followed by New value after clearing the text area',
#  'PWA app beforeInstallPrompt not firing in mobile browser but working in normal desktop browser',
#  'Production site is popping up sandbox.paypal payment window instead of just paypal.com payment window',
#  'copy feature branch code into master branch of another repository',
#  'Package Node.js app which runs as a service using node-windows',
#  'Android XzingScanner : How to customise ZxingScanner layout ? (add button)',
#  'Swift Firebase Authentication - two questions about error handling (im not sure how to name this errors)',
#  'How to retrieve a string which is located after a pattern in bash',
#  'Generating summary table at bottom of dataframe',
#  'Issue with ExoPlayer Mediabrowservice connection with ui and service using mvvm architecture',
#  'Exception in GridDB JAVA API',
#  'PubNub: TypeError: stat: path should be string, bytes, os.PathLike or integer, not NoneType',
#  'Add a neutral button to androidx EditTextPrefence / DialogPreference',
#  'How to use a pretrained tensorflowlite model for input interpretation',
#  'How to automatically create local href links?',
#  'JWT doesn&#39;t validate the token received',
#  'Xcode C++ code in cocoa app about serial port get operation not permitted',
#  'Change Legends and Node to an circle image',
#  'Manual Azure Backup Cosmos DB',
#  'Compiled web app with Google Sheet as database',
#  'How assign value for variable inside &quot;then&quot;?',
#  'Is Fragment can contain NavController?',
#  'Xamarin Forms change Tabbar to Toolbar using Shell Menu',
#  'How to write mocha test inside class',
#  'React-Native Android ScrollView can&#39;t get event from onScroll',
#  'How to show NuGet package dependencies?',
#  'Immersive mode in iOS Cordova apps - how to?',
#  'Panic running async code while dropping Rust Future',
#  'Finding the intersection of lat-long values in java',
#  'SQL Calculate Availability Percentage',
#  'Possible to trigger a build via github pr comment with some arguments',
#  'How can I search for a string prefix stored in an array of text?',
#  'Proportionally scaling an image and adding a border in React Native',
#  'TFS / AzureDevOps extension get unique user identity',
#  'How to send file using Chopper?',
#  'belongsTo–hasOne relationship returns null',
#  'Microsoft office.js Excel add-in - How to implement arrow style for a data series in a line chart?',
#  'How to insert sections and hyperlinks in google maps infobox',
#  'How can I change the recording audio device of SoX?',
#  'HAProxy settings for connecting to Snowflake Data',
#  'Java software not loading and returning StreamCorruptedException',
#  'Scraping Search function using Jsoup',
#  'phpMyAdmin is Not Showing the Create New Database field, what could be the reason',
#  'Record uniqueness when using NSPersistentCloudKitContainer?',
#  'Writing a server status board script',
#  'Passing argument to Delve debugger',
#  'want to increase previous and next page pagination icon size in material react table',
#  'Django-rest-auth registration with both Email and username (Please read the explanation carefully)',
#  'How to retrieve notification information using SharePoint webhooks',
#  'Repeating a command on bash until condition is met',
#  'High level transactions with states in a double entry accounting system',
#  'unt test for jest custom validation class (class-validator) and its message?',
#  'Hosting .net core and creating managed instances',
#  'creating turnjs instance before add any pages',
#  'Kubernetes MySQL pod stuck with CrashLoopBackOff',
#  'How do I change colour of Reveal Highlight in NavigationView in UWP?',
#  'GridDB Bad Connection Exception',
#  'Connecting to Sybase DB using Squirrel SQL Client - Driver Class not found Exception',
#  'Zeit Now Serverless Routing via Http Method',
#  'Refresh html frames for cross-domain sites out of my control',
#  'Piwik (Matomo) creating multiple visits in single session',
#  'Impute binary values in python',
#  'Unable to find read and write items and lists in all site collections permission in Azure Active Directory',
#  'Handling iframe Scroll from parent window ScrollBar',
#  'Jenkins git publisher permission',
#  'Need help to correctly perform wildcard search on a field',
#  'bundler: failed to load command: NameError',
#  'Getting value on XML string',
#  'Listening for messageReactionRemove for old reactions on old messages - Discord.JS',
#  'Summing Columns and replacing individual values if met specific condition',
#  'New Line on paragraph emelement &lt;br&gt; not working',
#  'Running all unit tests in Dart',
#  'What jars do I need for Spring AOP for version 5',
#  'Connect JavaScript to Python script with Flask',
#  'Outline Effect to Target Object',
#  'signUpUrl returning nullpointerexception',
#  'How to use .contains(nodeOrNodes) API when the contained react element has an arrow function event handler?',
#  'Passing security certificates using requests',
#  'Kiosk customization is not supported on my device',
#  'How to combine pyspark dataframes with different shapes and different columns',
#  'Problem getting messages after loading html between main and renderer',
#  'Why does OpenCV decomposed homography translation matrix have three values?',
#  'Unexpected behavior nested fields Big Query - Data Studio',
#  'Apache Beam - Batch Mode with Windows how to trigger window strategy?',
#  'GCloud VM Instance, LetsEncrypt SSL - 2 Sites: One Primary Domain, One Subdomain. Why is the SSL On Subdomain Redirecting To Primary Domain?',
#  'Why is statsmodels package not working on Flask but is on ipython?',
#  'using isdigit to inform any detected illegal characters',
#  'Detecting the most prominent color of an image with python or other programming language',
#  'Sails: Exclude directory from being auto loaded as helper',
#  'How to avoid Null Pointer Exception in Two Activities Communication',
#  'Why my fonction is called twice in storage.single?',
#  'Update BottomNavigationBar when tapping on Button',
#  'Hide posts from index page',
#  'Prevent FlatList from re renders when numColumns &gt; 1',
#  'WatchOS app not detecting companion iOS app',
#  'Batch Move Folders into Subfolders, Recursively',
#  'Celery/Flask/Redis - apply_async function doesn&#39;t work - Updated 2',
#  'AWS CDK CfnAnomalyDetector usage for CPUUtilization',
#  'Has anyone integrated CKAN with Qlik, Tableau, and R? How did you do it?',
#  'Consolidating an One to Many relationship in Thymeleaf',
#  'Adding a simple TagHelper causes this error: &quot;RenderBody has not been called for the page &quot;',
#  'Pop-up accept button can not be clicked by ROBOT Framework',
#  'Hive - find 2 characters anywhere in the string/row - RLIKE',
#  'Display child elements in a single row unless they overflow, then display a single column',
#  'Get ADUser sort by memberof not working for me',
#  'Converting a String to small caps pseudoalphabet in Java',
#  'Shell operators non-zero (-n) and zero length (-z) both return True for the same variable!!! Inconceivable',
#  'Blurring a Rect within a screenshot',
#  'Automatically select principle text-containing columns from data.frame?',
#  'Upgrade Angular 4 to Angular 8',
#  'How to create remote file node for contentful image',
#  'Modx Formit simple contact from',
#  'Redirected after submit form Formit Modx',
#  'How do I reflect data in excel?',
#  'Why does inotifywait stop working consistently after a git checkout on the files it&#39;s watching?',
#  'Why is my false conditional element fickering while route is loading?',
#  'Android: BottomSheetMenuItem doesn&#39;t show icon in Menu',
#  'NameError: name &#39;HTMLSession&#39; is not defined when calling yahoo_fin.options.get_expiration_dates()',
#  'How can I add a share to GraphQL Bin option to my Apollo server playground?',
#  'Floating action button not showing in bottomsheetfragment collapsed state',
#  'Postgres - create table very slow - with partition and BRIN index',
#  'Codeigniter - Append rows in view then add those rows to database table',
#  'How to zip each individual element from two lists into one list using OCaml',
#  'Restricting code review requests to service accounts',
#  'Is it possible and Edit an outgoing HTTP Request',
#  'How would I sort a nested list by the second element in a list and then output the second lowest element in the entire list?',
#  'Error: conflicting types when trying to make a simple syscall',
#  'Is it safe to clone a type-erased Arc via raw pointer?',
#  'Deserialization in pyomo of data constructed in mathematica',
#  'Firebase Twitter oAuth callback not working for Swift ios13',
#  'Can IPFS app hide the CID when presenting content to requester?',
#  'Getting the peer multiaddr from IPFS Swarm peers',
#  'qemu: uncaught target signal 11 (Segmentation fault) - core dumped, when trying to return a struct',
#  'Is it possible to share a folder for writes and updates between different IPFS nodes?',
#  'gstreamer&#39;s udpsink stops streaming after sending ~1000 packets',
#  'Sending files with python requests, file is SOMETIMES corrupted',
#  'R markdown, trouble with \\rowcolor in kable_styling()',
#  'Keycloak group-based policy to prevent user from accessing a client',
#  'Database compatability between releases of mediawiki',
#  'Docker-Compose: Why are my rails images having permission issues accessing MySQL databases?',
#  'nodemon Internal watch failed: watch /Users/admin/Library/Application Support/Code/1.26.1-shared.sock Unknown system error -102',
#  'Connection timeout using nodejs stompit when connecting to activemq artemis',
#  'Running functions on bluetooth pair request',
#  'How do I correctly create a reference to a Unity object?',
#  'Sequelize Multi Inserting Data',
#  'JavaScript files validation are failing in Eclipse under Maven project',
#  'How ro run sudo su - in Dockerfile',
#  'Highlighting country by hovering map using bokeh',
#  'Problems with zooming on mobile',
#  'Mapping of YAWL onto BPMN and vice versa',
#  'My font family cannot render &quot;straight quotes&quot;. What should I do?',
#  'How to use tensorflow 2.0 with AWS Lambda?',
#  'Concurrent hash table in C++',
#  'How to use &quot;IF and Button&quot; to change data in MySQL database',
#  'Understanding passport.authenticate(&#39;local&#39;) syntax bit',
#  'How to get correct year, month and day in firebird function datediff including leap years',
#  'Can I use pybind to load an external c++ dll and call functions?',
#  'Spring MVC App, in form:input path= converts given object to string, when I need the object to acces a value of the map',
#  'Need help on JavaScript async and await function',
#  'Spring Data Neo4j find nodes by a few arrays of ids',
#  'Is returning the same geolocation to different addresses, how to solve?',
#  'Typescript Release Mode and Debug Mode Configuration',
#  'How can I investigate my node-gyp &quot;build error&quot;?',
#  'How to get area, road with information like jam from HERE Api?',
#  'Basic cash system in C++',
#  'Android HERE SDK lite: Place Here logo to another',
#  'Insert values to a previous table in Qlik Sense',
#  'Need help for this tool in python',
#  'How to draw a rectangle in wxwidgets?',
#  'Need help in XSLT transformation for XML',
#  'After javascript submits form in rails 6 the update action in controller not launching update.js.erb',
#  '&quot;NoMethodError: undefined method `env&#39; for nil:NilClass&quot; for Helper testing in rails',
#  'asp.net core 3 identity generatePasswordResetTokenAsync causes internal error',
#  'Is there any way to dynamically convert a Jenkinsfile into a Drone.yml pipeline configuration?',
#  'How to properly truncate a staging table in an ETL pipeline?',
#  'match columns values qlikview',
#  'Inserting new event into CalDAV calendar using curl',
#  'Swift Vision VNFaceLandmarks2 class faceContour array direction changed to &quot;right-to-left&quot;',
#  'Does Google Speech To Text comply with RFC 6787',
#  'How to make library&#39;s transitive dependencies show up in app when using BillOfMaterials?',
#  'Using Jespa for Authenticating a AD Account through a Rest Service',
#  'Pygame when you press on key move image to position',
#  'Scilab algorithm - recursion',
#  'Alternative to using __file__ find the binary folder in my python package',
#  'Android POI Error when reading Word document: Provider com.bea.xml.stream.EventFactory not found',
#  'Sending JSON obj with Japanese characters from Python to Javascript',
#  'Is it possible to limit a Google service account to specific BigQuery datasets within a project?',
#  'Shared Preferences MODE_APPEND constant is not recognised',
#  'How to join two table without foreignkey with refrence uf uid',
#  'Flask X-Filters by backref',
#  'different entity group on transaction using google-cloud-ndb',
#  'Delphi Rio 10.3.2 Android FireDac SQLITE unable to open query - same code worked with Delphi Tokyo with same android device',
#  'neo4j : jQuery not returning expected result on apoc.load.html',
#  'Modify google calendar based on google spreadsheet data (prevent duplication)',
#  'Filling in a zero for all empty time bins for each cluster (region) as part of an ambulance response/posting analysis',
#  'Converting Java code to Clojure. Example creating Open Document File',
#  'API key not appending to ReverseGeocode request',
#  'tf.app.run(main=main, argv=[sys.argv[0]] + unparsed) AttributeError: module &#39;tensorflow&#39; has no attribute &#39;app&#39;',
#  'RawInput WinAPI: GetRawInputBuffer() and message handling',
#  'CakePHP 3.8 Change Form Data based on User Selection',
#  'Finding a perfect matching in graphs',
#  'Recreate Photoshop&#39;s &quot;mixer brush tool&quot; for painting iOS app',
#  'Searching between TreeView Nodes Powershell',
#  'How to deal with EventEmitter memory leaks in nodejs?',
#  'How to handle &quot;unsupported_grant_type&quot; from laravel passport',
#  'Python math.log function math domain error',
#  '2sxc Entity with a field that must be unique',
#  'Deploying Google Cloud Endpoints configuration fails Google API Linter recommendations',
#  'How to swap three by three elements in a prolog list?',
#  'Firebase listener with React Hooks',
#  'How to export large data from Postgres to S3 using Cloud composer?',
#  'How do I remove objects from an array of strings by keyword, or search for a specific object over the length of the array?',
#  'Change time of &#39;next_execution_date&#39; on Airflow in &#39;BashOperator&#39;',
#  'deg2km command does not calculate distance between two points in matlab',
#  'How to change OptaWeb Employee Rostering solver configuration',
#  'How to pass multiple where condition to the SQL in Symfony?',
#  'How to generate a random Scala Int in Chisel code?',
#  'How to conditionally drop rows in pandas',
#  'Setting Custom metadata to an object in Google Cloud Storage',
#  'SOLVED : &quot;android javax.net.ssl.SSLException: 502 AUTH TLS OK&quot; on HUAWEI smartphone but it works well on a SAMSUNG smartphone. Why?',
#  'Problem with bounds array shape in scipy.optimize constrained methods',
#  'Airflow export all tables of a postgres DB to BigQuery',
#  'How do I edit current shell command without executing it?',
#  'How can I add a custom Netty channel handler in Vert.x?',
#  'Is there a way in a seed_data.yaml file to autogenerate models on which first model is dependent upon?',
#  'I need to migrate Kotlin Corotine experimental functions to stable version',
#  'WKwebview is blank white screen when returning from cam scanner SDK in iOS Swift?',
#  'Updating glibc on linux mint for sbcl install',
#  'Problem opening files with the FileReader API',
#  'Solved - App crashes when removing data from Firebase',
#  'WPF Dispatcher Invoking with a Progress Bar',
#  'How to remove date chunk from bigger string without regex?',
#  'How to i play sound using the sound library in processing?',
#  'Django 1.11 middleware how to redirect properly',
#  'Build Failed when uploadCrashlyticsMappingFileRelease',
#  'Allow data traffic on Cellular device Win10 C#',
#  'Build failed with CrashlyticsOrgIdException',
#  'Why Hello World is not showing up?',
#  'Aurelia testing components with transient dependencies never uses a mock',
#  'Integrate &#181;Test (micro test) for Scala into a Gradle project',
#  'How to pass information from one reducer to another in MapReduce',
#  'Dynamic Timeslots with one hour intervals and dynamic intervals too',
#  'Why would -ms-grid-row not work if it comes before grid-row?',
#  'Referencing a workbook whose file name changes consistently - solution suggestions?',
#  'Link error after updating next js to v9 - Parameter &#39;url&#39; must be string, not undefined',
#  'WebRTC connection does not establish after successful signaling',
#  'ESLint configuration and peer dependencies',
#  'Mobius Form 3 Errors on 2sxc 10.25?',
#  'PhysicsBody: Could not create physics body',
#  'C# Vibration Sensor using External Accelerometer',
#  'How to completely hide title bar but not navigation bar in iOS 13 Swift',
#  'Can not blink the LED PA5 on Nucleo board',
#  'How to start activity from background in android 10 - android Q - MIUI 11',
#  'Mock DNS server using Twisted',
#  'Use PowerShell to save Word document as HTML with encoding']

# %%
answers = SITE.fetch('answers', fromdate=1577775600, todate=1580454000, sort='votes')

df = pd.DataFrame(answers)
df
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0         10      True     5        300              300      0
# 1         10      True     5        300              300      0
# 2         10      True     5        300              300      0
# 3         10      True     5        300              300      0
# 4         10      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495       10      True     5        300              300      0
# 496       10      True     5        300              300      0
# 497       10      True     5        300              300      0
# 498       10      True     5        300              300      0
# 499       10      True     5        300              300      0
#
#                                                  items
# 0    {'owner': {'reputation': 434373, 'user_id': 47...
# 1    {'owner': {'reputation': 122920, 'user_id': 20...
# 2    {'owner': {'reputation': 3400, 'user_id': 4768...
# 3    {'owner': {'reputation': 329836, 'user_id': 44...
# 4    {'owner': {'reputation': 11812, 'user_id': 687...
# ..                                                 ...
# 495  {'owner': {'reputation': 315, 'user_id': 50615...
# 496  {'owner': {'reputation': 287, 'user_id': 12076...
# 497  {'owner': {'reputation': 1396, 'user_id': 1001...
# 498  {'owner': {'reputation': 101783, 'user_id': 24...
# 499  {'owner': {'reputation': 6058, 'user_id': 3920...
#
# [500 rows x 7 columns]

# %%
items = df["items"]
items
# Out:
# 0      {'owner': {'reputation': 434373, 'user_id': 47...
# 1      {'owner': {'reputation': 122920, 'user_id': 20...
# 2      {'owner': {'reputation': 3400, 'user_id': 4768...
# 3      {'owner': {'reputation': 329836, 'user_id': 44...
# 4      {'owner': {'reputation': 11812, 'user_id': 687...
#                              ...
# 495    {'owner': {'reputation': 315, 'user_id': 50615...
# 496    {'owner': {'reputation': 287, 'user_id': 12076...
# 497    {'owner': {'reputation': 1396, 'user_id': 1001...
# 498    {'owner': {'reputation': 101783, 'user_id': 24...
# 499    {'owner': {'reputation': 6058, 'user_id': 3920...
# Name: items, Length: 500, dtype: object

# %%
items[0]
# Out:
# {'owner': {'reputation': 434373,
#   'user_id': 476,
#   'user_type': 'moderator',
#   'accept_rate': 70,
#   'profile_image': 'https://www.gravatar.com/avatar/a235706e3d81b614acaec3368edfea4b?s=128&d=identicon&r=PG',
#   'display_name': 'deceze',
#   'link': 'https://stackoverflow.com/users/476/deceze'},
#  'is_accepted': True,
#  'score': 162,
#  'last_activity_date': 1579597460,
#  'creation_date': 1579597460,
#  'answer_id': 59837471,
#  'question_id': 59837318}

# %%
answers_ids =[]

for key in range(len(items)):
    ids = items[key]["answer_id"]
    answers_ids.append(ids)
answers_ids
# Out:
# [59837471,
#  59593614,
#  59932434,
#  59734482,
#  59732251,
#  59710625,
#  59821083,
#  59871821,
#  59662728,
#  59764670,
#  59570894,
#  59638013,
#  59654562,
#  59837466,
#  59931774,
#  59654622,
#  59802795,
#  59927105,
#  59723047,
#  59600699,
#  59697523,
#  59928620,
#  59927626,
#  59592266,
#  59641565,
#  59571059,
#  59624180,
#  59721075,
#  59944244,
#  59716709,
#  59926663,
#  59927561,
#  59661137,
#  59855964,
#  59763928,
#  59785708,
#  59850271,
#  59749387,
#  59939032,
#  59555327,
#  59560481,
#  59723091,
#  59752184,
#  59772503,
#  59866061,
#  59578749,
#  59592193,
#  59623473,
#  59785411,
#  59883234,
#  59540812,
#  59711636,
#  59553083,
#  59571577,
#  59662832,
#  59764290,
#  59973360,
#  59588641,
#  59598356,
#  59742222,
#  59763776,
#  59764763,
#  59821066,
#  59923762,
#  59553383,
#  59593725,
#  59622442,
#  59781316,
#  59956445,
#  59596814,
#  59683349,
#  59816577,
#  59822596,
#  59899059,
#  59912342,
#  59931204,
#  59931269,
#  59542173,
#  59596270,
#  59598602,
#  59618812,
#  59662275,
#  59757534,
#  59800218,
#  59932487,
#  59551851,
#  59573424,
#  59583403,
#  59603115,
#  59654202,
#  59674716,
#  59707887,
#  59709311,
#  59731862,
#  59898149,
#  59553656,
#  59555335,
#  59563608,
#  59624963,
#  59626104,
#  59637568,
#  59644301,
#  59721161,
#  59743937,
#  59777553,
#  59841947,
#  59934413,
#  59543624,
#  59561214,
#  59588514,
#  59605583,
#  59624104,
#  59665314,
#  59684993,
#  59721171,
#  59749569,
#  59766072,
#  59792051,
#  59817527,
#  59871814,
#  59927138,
#  59563480,
#  59565587,
#  59596273,
#  59619504,
#  59624371,
#  59637894,
#  59647986,
#  59653181,
#  59662623,
#  59673999,
#  59682550,
#  59698030,
#  59708591,
#  59767166,
#  59810100,
#  59812090,
#  59821043,
#  59838926,
#  59860787,
#  59861129,
#  59906028,
#  59573430,
#  59591269,
#  59603509,
#  59613610,
#  59629918,
#  59661284,
#  59697128,
#  59701925,
#  59711254,
#  59744873,
#  59753140,
#  59753840,
#  59756730,
#  59770599,
#  59784782,
#  59800219,
#  59850183,
#  59867904,
#  59907370,
#  59936279,
#  59946363,
#  59952978,
#  59959505,
#  59541933,
#  59549617,
#  59563258,
#  59599445,
#  59607695,
#  59611899,
#  59613872,
#  59616399,
#  59617809,
#  59617889,
#  59624459,
#  59629258,
#  59637535,
#  59637578,
#  59650412,
#  59655464,
#  59655513,
#  59683632,
#  59689369,
#  59697186,
#  59707917,
#  59718781,
#  59721195,
#  59753610,
#  59763372,
#  59789113,
#  59789146,
#  59797740,
#  59809418,
#  59820089,
#  59826433,
#  59844549,
#  59849265,
#  59855971,
#  59868769,
#  59904780,
#  59905215,
#  59909679,
#  59923692,
#  59933474,
#  59953061,
#  59954447,
#  59549217,
#  59561899,
#  59579221,
#  59581102,
#  59584876,
#  59589932,
#  59592093,
#  59600668,
#  59604750,
#  59629075,
#  59646229,
#  59649578,
#  59668407,
#  59672586,
#  59697916,
#  59709134,
#  59715542,
#  59715704,
#  59717963,
#  59718502,
#  59718610,
#  59726034,
#  59735492,
#  59750212,
#  59754251,
#  59755062,
#  59756875,
#  59768299,
#  59768428,
#  59778999,
#  59779894,
#  59782931,
#  59785360,
#  59789373,
#  59795740,
#  59801212,
#  59802672,
#  59823184,
#  59823243,
#  59838756,
#  59842814,
#  59845291,
#  59859180,
#  59886139,
#  59889489,
#  59920866,
#  59937783,
#  59939254,
#  59949927,
#  59950740,
#  59956218,
#  59957154,
#  59959134,
#  59967977,
#  59979089,
#  59987131,
#  59988149,
#  59990646,
#  59546574,
#  59562136,
#  59563570,
#  59564039,
#  59575246,
#  59580932,
#  59581092,
#  59581853,
#  59594760,
#  59596274,
#  59602863,
#  59607047,
#  59613107,
#  59613525,
#  59627323,
#  59629973,
#  59630383,
#  59632012,
#  59632661,
#  59633853,
#  59636054,
#  59644498,
#  59646743,
#  59648043,
#  59649406,
#  59651946,
#  59652516,
#  59655005,
#  59659040,
#  59660110,
#  59666836,
#  59668380,
#  59683329,
#  59685122,
#  59687500,
#  59693978,
#  59694859,
#  59704492,
#  59707681,
#  59713120,
#  59716570,
#  59718059,
#  59723293,
#  59726235,
#  59730620,
#  59732647,
#  59734468,
#  59739464,
#  59774159,
#  59779410,
#  59781968,
#  59796695,
#  59802768,
#  59815117,
#  59820610,
#  59823370,
#  59825718,
#  59827572,
#  59833154,
#  59836176,
#  59839834,
#  59841485,
#  59842263,
#  59846217,
#  59847817,
#  59854094,
#  59856360,
#  59859998,
#  59865821,
#  59872522,
#  59892639,
#  59893294,
#  59910763,
#  59911734,
#  59918662,
#  59930656,
#  59934076,
#  59937635,
#  59951097,
#  59951701,
#  59955844,
#  59956938,
#  59959296,
#  59964935,
#  59967179,
#  59972232,
#  59978386,
#  59983774,
#  59987047,
#  59989653,
#  59991233,
#  59997967,
#  59543187,
#  59546034,
#  59546985,
#  59549099,
#  59549458,
#  59549679,
#  59553902,
#  59554461,
#  59554475,
#  59555181,
#  59555553,
#  59556676,
#  59557856,
#  59565524,
#  59568703,
#  59570277,
#  59571677,
#  59574487,
#  59579791,
#  59580148,
#  59582077,
#  59586077,
#  59587663,
#  59589004,
#  59589765,
#  59589851,
#  59599482,
#  59603120,
#  59607880,
#  59608348,
#  59612102,
#  59612988,
#  59614144,
#  59618168,
#  59618889,
#  59620353,
#  59626477,
#  59628727,
#  59629948,
#  59632467,
#  59633467,
#  59635277,
#  59635492,
#  59638710,
#  59641953,
#  59646477,
#  59652188,
#  59654461,
#  59654649,
#  59655402,
#  59655443,
#  59660067,
#  59667701,
#  59668811,
#  59669558,
#  59672237,
#  59672280,
#  59677234,
#  59678609,
#  59686314,
#  59687212,
#  59688255,
#  59689703,
#  59693227,
#  59697575,
#  59697622,
#  59697831,
#  59701224,
#  59705320,
#  59706454,
#  59706721,
#  59707230,
#  59718482,
#  59720775,
#  59722636,
#  59729080,
#  59731592,
#  59734347,
#  59734466,
#  59734484,
#  59736345,
#  59738026,
#  59739601,
#  59741873,
#  59742796,
#  59743285,
#  59743812,
#  59749007,
#  59749411,
#  59749553,
#  59750989,
#  59752087,
#  59753838,
#  59757544,
#  59761869,
#  59767136,
#  59767793,
#  59768794,
#  59769651,
#  59775294,
#  59777739,
#  59778850,
#  59780102,
#  59782830,
#  59783406,
#  59784536,
#  59788409,
#  59794831,
#  59802836,
#  59803771,
#  59817158,
#  59817659,
#  59818291,
#  59818867,
#  59824130,
#  59825747,
#  59827187,
#  59837521,
#  59841164,
#  59843726,
#  59844710,
#  59847257,
#  59849493,
#  59861265,
#  59865243,
#  59865468,
#  59868119,
#  59868125,
#  59869461,
#  59874280,
#  59879816,
#  59881721,
#  59883685,
#  59885137,
#  59886657,
#  59886779,
#  59887459,
#  59900997,
#  59903443,
#  59909621,
#  59910385,
#  59910958,
#  59911255]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
import datetime as dt
from datetime import datetime

today_HS_questions = SITE.fetch('questions', fromdate=datetime(2020,1,30), todate=datetime(2020,1,31), sort='votes', min = 5,  tag = "pyhton")
today_HS_questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['c', 'gcc', 'lambda', 'macros', 'function-pointers'],
#    'owner': {'reputation': 187,
#     'user_id': 9943262,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-xDAvMR0LPhY/AAAAAAAAAAI/AAAAAAAAADU/xdzmMsgOPeQ/photo.jpg?sz=128',
#     'display_name': 'Kish',
#     'link': 'https://stackoverflow.com/users/9943262/kish'},
#    'is_answered': True,
#    'view_count': 560,
#    'answer_count': 2,
#    'score': 17,
#    'last_activity_date': 1580481598,
#    'creation_date': 1580401247,
#    'last_edit_date': 1580434633,
#    'question_id': 59990270,
#    'link': 'https://stackoverflow.com/questions/59990270/how-does-the-lambda-macro-create-a-lambda',
#    'title': 'How does the lambda macro create a lambda?'},
#   {'tags': ['c++', 'c', 'argv', 'tocttou'],
#    'owner': {'reputation': 343,
#     'user_id': 5666053,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c133c35c22521e9427e8e28b3d2cfe0a?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Андрій Немченко',
#     'link': 'https://stackoverflow.com/users/5666053/%d0%90%d0%bd%d0%b4%d1%80%d1%96%d0%b9-%d0%9d%d0%b5%d0%bc%d1%87%d0%b5%d0%bd%d0%ba%d0%be'},
#    'is_answered': True,
#    'view_count': 179,
#    'accepted_answer_id': 59987131,
#    'answer_count': 2,
#    'score': 7,
#    'last_activity_date': 1580721296,
#    'creation_date': 1580390192,
#    'last_edit_date': 1580541289,
#    'question_id': 59986922,
#    'link': 'https://stackoverflow.com/questions/59986922/can-argv-be-changed-at-runtime-not-by-the-app-itself',
#    'title': 'Can argv be changed at runtime (not by the app itself)'},
#   {'tags': ['multithreading', 'haskell', 'concurrency', 'timeout', 'blocking'],
#    'owner': {'reputation': 225,
#     'user_id': 4137443,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/2123d4798a0a7a331ba33b6dd14ef01f?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Random dude',
#     'link': 'https://stackoverflow.com/users/4137443/random-dude'},
#    'is_answered': True,
#    'view_count': 81,
#    'accepted_answer_id': 59991233,
#    'answer_count': 1,
#    'score': 7,
#    'last_activity_date': 1580408535,
#    'creation_date': 1580393543,
#    'last_edit_date': 1580402334,
#    'question_id': 59987940,
#    'link': 'https://stackoverflow.com/questions/59987940/haskell-computationally-intensive-thread-blocks-all-other-threads',
#    'title': 'Haskell computationally intensive thread blocks all other threads'},
#   {'tags': ['julia'],
#    'owner': {'reputation': 71,
#     'user_id': 12815525,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bba802c25c5b8d6e91d2ca6e93733474?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Jon',
#     'link': 'https://stackoverflow.com/users/12815525/jon'},
#    'is_answered': True,
#    'view_count': 72,
#    'answer_count': 1,
#    'score': 7,
#    'last_activity_date': 1580408459,
#    'creation_date': 1580406472,
#    'last_edit_date': 1580408135,
#    'question_id': 59991708,
#    'link': 'https://stackoverflow.com/questions/59991708/how-to-read-binary-file-in-julia',
#    'title': 'How to read binary file in Julia?'},
#   {'tags': ['python'],
#    'owner': {'user_type': 'does_not_exist', 'display_name': 'user12815863'},
#    'is_answered': False,
#    'view_count': 71,
#    'closed_date': 1580456885,
#    'answer_count': 1,
#    'score': 7,
#    'last_activity_date': 1580411286,
#    'creation_date': 1580410811,
#    'question_id': 59992788,
#    'link': 'https://stackoverflow.com/questions/59992788/is-there-a-library-for-converting-a-traceback-to-its-exception',
#    'closed_reason': 'Off-topic',
#    'title': 'Is there a library for converting a traceback to its exception?'},
#   {'tags': ['javascript', 'java'],
#    'owner': {'reputation': 1684,
#     'user_id': 4759176,
#     'user_type': 'registered',
#     'accept_rate': 74,
#     'profile_image': 'https://i.stack.imgur.com/0U1e5.jpg?s=128&g=1',
#     'display_name': 'parsecer',
#     'link': 'https://stackoverflow.com/users/4759176/parsecer'},
#    'is_answered': True,
#    'view_count': 133,
#    'answer_count': 2,
#    'score': 7,
#    'last_activity_date': 1580419331,
#    'creation_date': 1580418016,
#    'last_edit_date': 1580418477,
#    'question_id': 59994440,
#    'link': 'https://stackoverflow.com/questions/59994440/javascript-function-rewritten-in-java-gives-different-results',
#    'title': 'Javascript function rewritten in Java gives different results'},
#   {'tags': ['javascript', 'react-native'],
#    'owner': {'reputation': 63,
#     'user_id': 12810198,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/11265845066edea33f30f90831c526fc?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Rapha-Y',
#     'link': 'https://stackoverflow.com/users/12810198/rapha-y'},
#    'is_answered': True,
#    'view_count': 33,
#    'accepted_answer_id': 59978102,
#    'answer_count': 1,
#    'score': 6,
#    'last_activity_date': 1580349508,
#    'creation_date': 1580348027,
#    'question_id': 59977957,
#    'link': 'https://stackoverflow.com/questions/59977957/how-to-call-for-more-than-one-functions-in-onpress-prop',
#    'title': 'How to call for more than one functions in onPress prop?'},
#   {'tags': ['java', 'java-8', 'annotations', 'compatibility'],
#    'owner': {'reputation': 76679,
#     'user_id': 4856258,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/d9ea19ceff450eb6e272da697ced62dc?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Tagir Valeev',
#     'link': 'https://stackoverflow.com/users/4856258/tagir-valeev'},
#    'is_answered': True,
#    'view_count': 227,
#    'answer_count': 1,
#    'score': 6,
#    'last_activity_date': 1580354672,
#    'creation_date': 1580354672,
#    'question_id': 59978673,
#    'link': 'https://stackoverflow.com/questions/59978673/what-are-the-compatibility-risks-of-replacing-method-field-etc-targets-with-typ',
#    'title': 'What are the compatibility risks of replacing METHOD/FIELD/etc. targets with TYPE_USE'},
#   {'tags': ['exception', 'try-catch', 'raku'],
#    'owner': {'reputation': 567,
#     'user_id': 12468200,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/63c0552c1520040a808d5d03d0bfee64?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'jakar',
#     'link': 'https://stackoverflow.com/users/12468200/jakar'},
#    'is_answered': True,
#    'view_count': 56,
#    'accepted_answer_id': 59983774,
#    'answer_count': 2,
#    'score': 6,
#    'last_activity_date': 1580398426,
#    'creation_date': 1580378337,
#    'question_id': 59983325,
#    'link': 'https://stackoverflow.com/questions/59983325/distinguish-between-exception-and-failure-in-a-catch-block-raku',
#    'title': 'Distinguish between Exception and Failure in a CATCH block [ RAKU ]'},
#   {'tags': ['android',
#     'android-viewpager',
#     'dagger-2',
#     'androidx',
#     'android-mvvm'],
#    'owner': {'reputation': 1563,
#     'user_id': 6341943,
#     'user_type': 'registered',
#     'accept_rate': 62,
#     'profile_image': 'https://i.stack.imgur.com/wqhTp.png?s=128&g=1',
#     'display_name': 'hushed_voice',
#     'link': 'https://stackoverflow.com/users/6341943/hushed-voice'},
#    'is_answered': False,
#    'view_count': 49,
#    'answer_count': 1,
#    'score': 6,
#    'last_activity_date': 1580455952,
#    'creation_date': 1580387774,
#    'question_id': 59986199,
#    'link': 'https://stackoverflow.com/questions/59986199/how-to-use-dagger-2-to-inject-viewmodel-of-same-fragments-inside-viewpager',
#    'title': 'How to use Dagger 2 to Inject ViewModel of same Fragments inside ViewPager'},
#   {'tags': ['java', 'arrays', 'json', 'file', 'object'],
#    'owner': {'reputation': 61,
#     'user_id': 12814644,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8958355b4b971b1fc9ced46d2cbe8362?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Marie_Jane98',
#     'link': 'https://stackoverflow.com/users/12814644/marie-jane98'},
#    'is_answered': True,
#    'view_count': 56,
#    'answer_count': 2,
#    'score': 6,
#    'last_activity_date': 1580456496,
#    'creation_date': 1580397430,
#    'question_id': 59989108,
#    'link': 'https://stackoverflow.com/questions/59989108/parsing-objects-arrays-from-json-to-java',
#    'title': 'Parsing Objects/Arrays from JSON to Java'},
#   {'tags': ['javascript',
#     'reactjs',
#     'firebase',
#     'google-cloud-firestore',
#     'react-hooks'],
#    'owner': {'reputation': 4162,
#     'user_id': 2860931,
#     'user_type': 'registered',
#     'accept_rate': 58,
#     'profile_image': 'https://www.gravatar.com/avatar/968ddbc21b4695b3fba4665b69d231b5?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Mel',
#     'link': 'https://stackoverflow.com/users/2860931/mel'},
#    'is_answered': False,
#    'view_count': 125,
#    'bounty_amount': 200,
#    'bounty_closes_date': 1581207027,
#    'answer_count': 2,
#    'score': 5,
#    'last_activity_date': 1580671121,
#    'creation_date': 1580346995,
#    'last_edit_date': 1580625584,
#    'question_id': 59977856,
#    'link': 'https://stackoverflow.com/questions/59977856/firebase-listener-with-react-hooks',
#    'title': 'Firebase listener with React Hooks'},
#   {'tags': ['vim', 'restructuredtext'],
#    'owner': {'reputation': 424,
#     'user_id': 10051099,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-zEhaK71cFsM/AAAAAAAAAAI/AAAAAAAAAAA/AAnnY7pY3uj2Rs4X15NaJSIsOYxNzX4COQ/mo/photo.jpg?sz=128',
#     'display_name': 'Yohei',
#     'link': 'https://stackoverflow.com/users/10051099/yohei'},
#    'is_answered': True,
#    'view_count': 41,
#    'accepted_answer_id': 59979089,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1580358542,
#    'creation_date': 1580358036,
#    'question_id': 59979024,
#    'link': 'https://stackoverflow.com/questions/59979024/how-to-input-hyphen-as-many-as-the-number-of-characters-in-the-line-above',
#    'title': 'How to input hyphen as many as the number of characters in the line above?'},
#   {'tags': ['c++', 'templates', 'c++17', 'sfinae'],
#    'owner': {'reputation': 117,
#     'user_id': 10106434,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-zzZsLoDW2gs/AAAAAAAAAAI/AAAAAAAAAIg/dUrzkhXaOXc/photo.jpg?sz=128',
#     'display_name': 'funnypig run',
#     'link': 'https://stackoverflow.com/users/10106434/funnypig-run'},
#    'is_answered': True,
#    'view_count': 98,
#    'accepted_answer_id': 59980915,
#    'answer_count': 2,
#    'score': 5,
#    'last_activity_date': 1580385560,
#    'creation_date': 1580365852,
#    'last_edit_date': 1580371207,
#    'question_id': 59980253,
#    'link': 'https://stackoverflow.com/questions/59980253/c-expression-sfinae-and-ostream-manipulators',
#    'title': 'C++ expression SFINAE and ostream manipulators'},
#   {'tags': ['javascript', 'reactjs', 'react-hooks'],
#    'owner': {'reputation': 1742,
#     'user_id': 8433471,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5050b487a92ece30c34c817359c22fee?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'ManavM',
#     'link': 'https://stackoverflow.com/users/8433471/manavm'},
#    'is_answered': True,
#    'view_count': 108,
#    'bounty_amount': 50,
#    'bounty_closes_date': 1581171485,
#    'answer_count': 4,
#    'score': 5,
#    'last_activity_date': 1580716031,
#    'creation_date': 1580382996,
#    'last_edit_date': 1580716031,
#    'question_id': 59984783,
#    'link': 'https://stackoverflow.com/questions/59984783/default-props-in-stateful-using-hooks-functional-components',
#    'title': 'Default Props in stateful (using hooks) functional components'},
#   {'tags': ['fortran', 'gfortran', 'intel-fortran', 'fortran2003'],
#    'owner': {'reputation': 2574,
#     'user_id': 2075630,
#     'user_type': 'registered',
#     'accept_rate': 56,
#     'profile_image': 'https://www.gravatar.com/avatar/8e938535dfc85999055798b79dd803dc?s=128&d=identicon&r=PG',
#     'display_name': 'kdb',
#     'link': 'https://stackoverflow.com/users/2075630/kdb'},
#    'is_answered': True,
#    'view_count': 93,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1580396017,
#    'creation_date': 1580385257,
#    'question_id': 59985499,
#    'link': 'https://stackoverflow.com/questions/59985499/are-fortrans-final-subroutines-reliable-enough-for-practical-use',
#    'title': 'Are Fortran&#39;s &quot;final&quot; subroutines reliable enough for practical use?'},
#   {'tags': ['javascript', 'chart.js'],
#    'owner': {'reputation': 223,
#     'user_id': 10474530,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/86a55469724408dd7fb6959761493999?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'InFlames82',
#     'link': 'https://stackoverflow.com/users/10474530/inflames82'},
#    'is_answered': True,
#    'view_count': 58,
#    'accepted_answer_id': 60000077,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1580458111,
#    'creation_date': 1580386747,
#    'last_edit_date': 1580388038,
#    'question_id': 59985918,
#    'link': 'https://stackoverflow.com/questions/59985918/how-to-display-only-one-label-in-a-multi-line-char',
#    'title': 'How to display only one label in a multi line char?'},
#   {'tags': ['java', 'java-8', 'java-stream', 'collectors'],
#    'owner': {'reputation': 1163,
#     'user_id': 2781389,
#     'user_type': 'registered',
#     'accept_rate': 46,
#     'profile_image': 'https://www.gravatar.com/avatar/1318cec3ac65137a45669e87f30e06df?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'M06H',
#     'link': 'https://stackoverflow.com/users/2781389/m06h'},
#    'is_answered': True,
#    'view_count': 66,
#    'accepted_answer_id': 59987630,
#    'answer_count': 2,
#    'score': 5,
#    'last_activity_date': 1580392590,
#    'creation_date': 1580391964,
#    'last_edit_date': 1580392590,
#    'question_id': 59987461,
#    'link': 'https://stackoverflow.com/questions/59987461/java-8-stream-function-grouping-to-map-where-value-is-a-map',
#    'title': 'Java 8 Stream function grouping to Map where value is a Map'},
#   {'tags': ['java'],
#    'owner': {'reputation': 345,
#     'user_id': 5274291,
#     'user_type': 'registered',
#     'accept_rate': 75,
#     'profile_image': 'https://lh4.googleusercontent.com/-oAGB5agToAo/AAAAAAAAAAI/AAAAAAAAABU/_pfvVxJfu_4/photo.jpg?sz=128',
#     'display_name': 'Jo&#227;o Pedro Schmitt',
#     'link': 'https://stackoverflow.com/users/5274291/jo%c3%a3o-pedro-schmitt'},
#    'is_answered': True,
#    'view_count': 94,
#    'closed_date': 1580393156,
#    'accepted_answer_id': 59987833,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1580395834,
#    'creation_date': 1580392901,
#    'question_id': 59987745,
#    'link': 'https://stackoverflow.com/questions/59987745/long-and-double-comparison-behaves-differently',
#    'closed_reason': 'Duplicate of…',
#    'title': 'Long and Double comparison (==) behaves differently'},
#   {'tags': ['c', 'printf'],
#    'owner': {'reputation': 61,
#     'user_id': 12814772,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mCnF1PFpDMFjIHD4jtgfceaLolgOkdjf-ZhvZXN=k-s128',
#     'display_name': 'beta_me me_beta',
#     'link': 'https://stackoverflow.com/users/12814772/beta-me-me-beta'},
#    'is_answered': True,
#    'view_count': 230,
#    'closed_date': 1580431978,
#    'accepted_answer_id': 59989653,
#    'answer_count': 3,
#    'score': 5,
#    'last_activity_date': 1580463495,
#    'creation_date': 1580398958,
#    'last_edit_date': 1580463495,
#    'question_id': 59989585,
#    'link': 'https://stackoverflow.com/questions/59989585/why-is-affecting-the-return-value-of-printf',
#    'closed_reason': 'Duplicate of…',
#    'title': 'Why is `\\` affecting the return value of printf?'},
#   {'tags': ['c++', 'pointers', 'null', 'literals', 'nullptr'],
#    'owner': {'reputation': 3953,
#     'user_id': 12139179,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a50aa08ca41bf24e8478a9b4dbc067c3?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'RobertS supports Monica Cellio',
#     'link': 'https://stackoverflow.com/users/12139179/roberts-supports-monica-cellio'},
#    'is_answered': True,
#    'view_count': 87,
#    'accepted_answer_id': 59990291,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1580402665,
#    'creation_date': 1580400786,
#    'last_edit_date': 1580402665,
#    'question_id': 59990138,
#    'link': 'https://stackoverflow.com/questions/59990138/what-is-the-difference-between-a-null-pointer-constant-nullptr-a-null-pointer',
#    'title': 'What is the difference between a null pointer constant (nullptr), a null pointer value and a null member pointer value?'},
#   {'tags': ['c#', 'json.net'],
#    'owner': {'reputation': 173,
#     'user_id': 5013066,
#     'user_type': 'registered',
#     'accept_rate': 75,
#     'profile_image': 'https://graph.facebook.com/973236816042283/picture?type=large',
#     'display_name': 'Eleanor Holley',
#     'link': 'https://stackoverflow.com/users/5013066/eleanor-holley'},
#    'is_answered': True,
#    'view_count': 97,
#    'accepted_answer_id': 59990771,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1580409575,
#    'creation_date': 1580402507,
#    'last_edit_date': 1580409575,
#    'question_id': 59990623,
#    'link': 'https://stackoverflow.com/questions/59990623/why-does-the-newtonsoft-deserializer-not-deserialize-a-smart-getter',
#    'title': 'Why does the Newtonsoft deserializer not deserialize a smart getter?'},
#   {'tags': ['perl', 'filehandle'],
#    'owner': {'reputation': 127,
#     'user_id': 6881511,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7fb1571eb297c04fea56c9d6cd73fad0?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'zubenel',
#     'link': 'https://stackoverflow.com/users/6881511/zubenel'},
#    'is_answered': True,
#    'view_count': 124,
#    'accepted_answer_id': 59991557,
#    'answer_count': 3,
#    'score': 5,
#    'last_activity_date': 1580482879,
#    'creation_date': 1580404910,
#    'question_id': 59991322,
#    'link': 'https://stackoverflow.com/questions/59991322/multiple-filehandles-opening-the-same-file-is-it-a-good-practice',
#    'title': 'Multiple filehandles opening the same file - is it a good practice?'},
#   {'tags': ['python',
#     'multithreading',
#     'python-multiprocessing',
#     'python-multithreading',
#     'ping'],
#    'owner': {'reputation': 285,
#     'user_id': 12339133,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f117454872df5894b4b948b3011196a7?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'AlbinoRhino',
#     'link': 'https://stackoverflow.com/users/12339133/albinorhino'},
#    'is_answered': True,
#    'view_count': 155,
#    'answer_count': 4,
#    'score': 5,
#    'last_activity_date': 1580488093,
#    'creation_date': 1580415783,
#    'question_id': 59993940,
#    'link': 'https://stackoverflow.com/questions/59993940/pinging-100-000-servers-is-multithreading-or-multiprocessing-better',
#    'title': 'pinging ~ 100,000 servers, is multithreading or multiprocessing better?'},
#   {'tags': ['java', 'arrays', 'memory', 'multidimensional-array'],
#    'owner': {'reputation': 53,
#     'user_id': 9043485,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-Np6IQ26GeG8/AAAAAAAAAAI/AAAAAAAAAQc/O8AQNcajHEY/photo.jpg?sz=128',
#     'display_name': 'Simon',
#     'link': 'https://stackoverflow.com/users/9043485/simon'},
#    'is_answered': True,
#    'view_count': 52,
#    'accepted_answer_id': 59995706,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1580424774,
#    'creation_date': 1580422509,
#    'question_id': 59995320,
#    'link': 'https://stackoverflow.com/questions/59995320/switching-out-array-sizes-in-2d-array-takes-different-amount-of-memory',
#    'title': 'Switching out array sizes in 2d array takes different amount of memory'}]}

# %%
df_today_HS_Q = pd.DataFrame(today_HS_questions)

items = df_today_HS_Q["items"].head(11)
items
# Out:
# 0     {'tags': ['c', 'gcc', 'lambda', 'macros', 'fun...
# 1     {'tags': ['c++', 'c', 'argv', 'tocttou'], 'own...
# 2     {'tags': ['multithreading', 'haskell', 'concur...
# 3     {'tags': ['julia'], 'owner': {'reputation': 71...
# 4     {'tags': ['python'], 'owner': {'user_type': 'd...
# 5     {'tags': ['javascript', 'java'], 'owner': {'re...
# 6     {'tags': ['javascript', 'react-native'], 'owne...
# 7     {'tags': ['java', 'java-8', 'annotations', 'co...
# 8     {'tags': ['exception', 'try-catch', 'raku'], '...
# 9     {'tags': ['android', 'android-viewpager', 'dag...
# 10    {'tags': ['java', 'arrays', 'json', 'file', 'o...
# Name: items, dtype: object

# %%
top_10_HS_Q = []
for question in range(len(items)):
    questions = items[question]["title"]
    top_10_HS_Q.append(questions)
    
top_10_HS_Q
# Out:
# ['How does the lambda macro create a lambda?',
#  'Can argv be changed at runtime (not by the app itself)',
#  'Haskell computationally intensive thread blocks all other threads',
#  'How to read binary file in Julia?',
#  'Is there a library for converting a traceback to its exception?',
#  'Javascript function rewritten in Java gives different results',
#  'How to call for more than one functions in onPress prop?',
#  'What are the compatibility risks of replacing METHOD/FIELD/etc. targets with TYPE_USE',
#  'Distinguish between Exception and Failure in a CATCH block [ RAKU ]',
#  'How to use Dagger 2 to Inject ViewModel of same Fragments inside ViewPager',
#  'Parsing Objects/Arrays from JSON to Java']

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answers = SITE.fetch('answers', ids=[6784, 6473])

# %%
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28539,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}
