# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import requests

from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %%
import pandas as pd

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
questions = SITE.fetch('questions', fromdate=1577775600, todate=1580454000)

# %%
df = pd.DataFrame(questions)
df
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'tags': ['java', 'multithreading', 'synchroni...
# 1    {'tags': ['asp.net-mvc', 'entity-framework', '...
# ...

# %%
items = df["items"]
items
# Out:
# 0      {'tags': ['java', 'multithreading', 'synchroni...
# 1      {'tags': ['asp.net-mvc', 'entity-framework', '...
# 2      {'tags': ['android', 'kotlin', 'navigation', '...
# 3      {'tags': ['firebase', 'flutter', 'google-cloud...
# 4      {'tags': ['wpf', 'powershell', 'grid'], 'owner...
#                              ...
# 495    {'tags': ['ibm-integration-bus', 'extended-sql...
# 496    {'tags': ['macos', 'shell', 'mdm', 'kernel-ext...
# 497    {'tags': ['excel', 'jxls'], 'owner': {'reputat...
# 498    {'tags': ['android-studio', 'drawable'], 'owne...
# 499    {'tags': ['angular', 'ionic-framework', 'ionic...
# Name: items, Length: 500, dtype: object

# %%
items[0]
# Out:
# {'tags': ['java', 'multithreading', 'synchronized'],
#  'owner': {'reputation': 697,
#   'user_id': 6865330,
#   'user_type': 'registered',
#   'accept_rate': 33,
#   'profile_image': 'https://i.stack.imgur.com/OGNmd.png?s=128&g=1',
#   'display_name': 'Alan',
#   'link': 'https://stackoverflow.com/users/6865330/alan'},
#  'is_answered': False,
#  'view_count': 90,
#  'answer_count': 3,
#  'score': 1,
#  'last_activity_date': 1580662807,
#  'creation_date': 1580154666,
#  'last_edit_date': 1580563715,
#  'question_id': 59937947,
#  'link': 'https://stackoverflow.com/questions/59937947/both-threads-stuck-on-wait-condition-in-java',
#  'title': 'Both Threads stuck on wait condition in Java'}

# %%
questions_of_the_month = []
for item in range(len(items)):
    question = df["items"][item]["title"]
    questions_of_the_month.append(question)
    
questions_of_the_month

# %%
questions_of_the_month_ids= []

for ids in range(len(items)):
    question_id = df["items"][ids]["question_id"]
    questions_of_the_month_ids.append(question_id)

questions_of_the_month_ids

# %%
answers = SITE.fetch("questions/{ids}/answers", ids = [questions_of_the_month_ids])

# ERROR, TO CHECK

# %%
#ALTERNATIVE SOLUTION

answers = SITE.fetch('answers', fromdate=1577775600, todate=1580454000, sort='votes')

df = pd.DataFrame(answers)
df

# %%
items = df["items"]
items

# %%
items[0]

# %%
answers_ids =[]

for key in range(len(items)):
    ids = items[key]["answer_id"]
    answers_ids.append(ids)
answers_ids
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-c444c8b25400> in <module>
#       2
#       3 for key in range(len(items)):
# ----> 4     ids = items[key]["answer_id"]
#       5     answers_ids.append(ids)
#       6 answers_ids
#
# KeyError: 'answer_id'

# %%
answers = SITE.fetch('answers/{ids}', ids=[answers_ids])
answers
 
# ERROR, TO CHECK

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
import datetime as dt
from datetime import datetime

today_HS_questions = SITE.fetch('questions', fromdate=datetime(2020,1,30), todate=datetime(2020,1,31), sort='votes', min = 5,  tag = "pyhton")
today_HS_questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['c', 'gcc', 'lambda', 'macros', 'function-pointers'],
#    'owner': {'reputation': 187,
#     'user_id': 9943262,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-xDAvMR0LPhY/AAAAAAAAAAI/AAAAAAAAADU/xdzmMsgOPeQ/photo.jpg?sz=128',
#     'display_name': 'Kish',
#     'link': 'https://stackoverflow.com/users/9943262/kish'},
#    'is_answered': True,
#    'view_count': 554,
#    'answer_count': 2,
#    'score': 17,
#    'last_activity_date': 1580481598,
#    'creation_date': 1580401247,
#    'last_edit_date': 1580434633,
#    'question_id': 59990270,
#    'link': 'https://stackoverflow.com/questions/59990270/how-does-the-lambda-macro-create-a-lambda',
#    'title': 'How does the lambda macro create a lambda?'},
#   {'tags': ['multithreading', 'haskell', 'concurrency', 'timeout', 'blocking'],
# ...

# %%
df_today_HS_Q = pd.DataFrame(today_HS_questions)

items = df_today_HS_Q["items"].head(11)
items
# Out:
# 0     {'tags': ['c', 'gcc', 'lambda', 'macros', 'fun...
# 1     {'tags': ['multithreading', 'haskell', 'concur...
# 2     {'tags': ['julia'], 'owner': {'reputation': 71...
# 3     {'tags': ['python'], 'owner': {'user_type': 'd...
# 4     {'tags': ['javascript', 'java'], 'owner': {'re...
# 5     {'tags': ['javascript', 'react-native'], 'owne...
# 6     {'tags': ['java', 'java-8', 'annotations', 'co...
# 7     {'tags': ['exception', 'try-catch', 'raku'], '...
# 8     {'tags': ['android', 'android-viewpager', 'dag...
# 9     {'tags': ['c++', 'c', 'argv', 'tocttou'], 'own...
# 10    {'tags': ['java', 'arrays', 'json', 'file', 'o...
# Name: items, dtype: object

# %%
top_10_HS_Q = []
for question in range(len(items)):
    questions = items[question]["title"]
    top_10_HS_Q.append(questions)
    
top_10_HS_Q
# Out:
# ['How does the lambda macro create a lambda?',
#  'Haskell computationally intensive thread blocks all other threads',
#  'How to read binary file in Julia?',
#  'Is there a library for converting a traceback to its exception?',
#  'Javascript function rewritten in Java gives different results',
#  'How to call for more than one functions in onPress prop?',
#  'What are the compatibility risks of replacing METHOD/FIELD/etc. targets with TYPE_USE',
#  'Distinguish between Exception and Failure in a CATCH block [ RAKU ]',
#  'How to use Dagger 2 to Inject ViewModel of same Fragments inside ViewPager',
#  'Can argv be changed at runtime (not by the app itself)',
#  'Parsing Objects/Arrays from JSON to Java']

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answers = SITE.fetch('answers/{}', ids=[6784, 6473])
answers = SITE.fetch('answers/{ids}', ids=[6784, 6473])
#ERROR, TO CHECK
# Out:
# ---------------------------------------------------------------------------
# StackAPIError                             Traceback (most recent call last)
# <ipython-input-44-5084f489a915> in <module>
# ----> 1 answers = SITE.fetch('answers/{}', ids=[6784, 6473])
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/stackapi/stackapi.py in fetch(self, endpoint, page, key, filter, **kwargs)
#     196                 code = response["error_name"]
#     197                 message = response["error_message"]
# --> 198                 raise StackAPIError(self._previous_call, error, code, message)
#     199             except KeyError:
#     200                 pass  # This means there is no error
#
# StackAPIError: ('https://api.stackexchange.com/2.2/answers/%7B%7D/6784;6473/?pagesize=100&page=1&filter=default&site=stackoverflow', 404, 'no_method', 'no method found with this name')
